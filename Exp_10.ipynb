# %% [markdown]
# #Name- Dhruv Patil
# #PRN- 25070123146
# #Experiment-10
# #Aim- Study of Pandas library

# %%
#Introduction to Pandas
# Pandas: Panel Data
'''Used for:
Structured data
EDA
Data cleaning'''
# Out:
# 'Used for:\nStructured data\nEDA\nData cleaning'

# %%
#1. Import and printing panda series:
import pandas as pd
s= pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#2. Create DataFrame
data={
    "Name":["A","B","C"],
    "Marks":[85,90,78]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
#3. Find the Structure of the Dataframe
df.shape
# Out:
# (3, 2)

# %%
#4. Size of Dataframe
df.size
# Out:
# 6

# %%
#5. Display Column Names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
#Display dimensions
df.ndim
# Out:
# 2

# %%
#6. Check Data Types of each columns
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
#7. Access Individual Column
df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
#8. Access specific row
df.loc[1]
# Out:
# Name      B
# Marks    90
# Name: 1, dtype: object

# %%
df.head()
df.tail()
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
df.iloc[1,1]
# Out:
# np.int64(90)

# %%
#9. Add a new column:
'''If marks 80-90-first class
If marks>=90-Distinction
If marks>80-Second class'''
df["Grade"]=["First Class","Distinction","Second Class"]
display(df)
# Out:
#   Name  Marks         Grade
# 0    A     85   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
#10. Update data in data frame,
    #Change marks of student A to 88.
df.iloc[0,1]=81
df
# Out:
#   Name  Marks         Grade
# 0    A     81   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
df.loc[1,"Marks"]=95
df
# Out:
#   Name  Marks         Grade
# 0    A     81   First Class
# 1    B     95   Distinction
# 2    C     78  Second Class

# %%
#11. Delete a column
df.drop("Grade", axis=1, inplace=True)
df
# Out:
#   Name  Marks
# 0    A     81
# 1    B     95
# 2    C     78

# %%
new_df=df.drop("Name",axis=1)
display("the new column is:",new_df)
print()
# Out:
# 'the new column is:'
#    Marks
# 0     81
# 1     95
# 2     78

# %%
#12. To perform basic statistical analysis
mean1=df["Marks"].mean()
mean1
# Out:
# np.float64(84.66666666666667)

# %%
min1=df["Marks"].min()
min1
# Out:
# 78

# %%
max1=df["Marks"].max()
max1
# Out:
# 95

# %%
#13. Apply condition (filtering)
#Display students scoring more than 80.
df[df["Marks"]>80]
# Out:
#   Name  Marks
# 0    A     81
# 1    B     95
